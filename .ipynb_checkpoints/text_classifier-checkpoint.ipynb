# %% [markdown]
# # <span style="color:red">Importing Data and getting initial info</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import seaborn as sns

from unidecode import unidecode
from nltk.tokenize import WordPunctTokenizer
from nltk.corpus import stopwords
from nltk.stem import RSLPStemmer
from wordcloud import WordCloud
from string import punctuation

# UNCOMMENT THIS PART WHEN RUNNING THIS NOTEBOOK FOR THE FIRST TIME
# nltk.download()

# %%
data = pd.read_csv("./data/feed_2020-02-24.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            1000 non-null   int64
#  1   Title         1000 non-null   object
#  2   Image         1000 non-null   object
#  3   Link          1000 non-null   object
#  4   Category      1000 non-null   object
#  5   Content       1000 non-null   object
#  6   Created at    1000 non-null   object
#  7   Updated at    1000 non-null   object
#  8   Button text   997 non-null    object
#  9   Pick count    1000 non-null   int64
#  10  Collectible   1000 non-null   bool
#  11  Published at  1000 non-null   object
#  12  Platform      1000 non-null   object
# dtypes: bool(1), int64(2), object(10)
# memory usage: 94.9+ KB

# %% [markdown]
# # <span style="color:red">Data Pre-processing</span>

# %%
feed_news = data.query('Category == "news"').copy()
feed_news = feed_news[['Id', 'Title', 'Content']]

# %% [markdown]
# ### Creating a column with title and content together

# %%
feed_news['Title_and_Content'] = feed_news['Title'] + ' ' + feed_news['Content']

# %% [markdown]
# ### Transforming text to lower_case

# %%
feed_news['Title_and_Content'] = feed_news['Title_and_Content'].str.lower()

# %% [markdown]
# ### Removing stopwords

# %%
pattern = r'\b(?:{})\b'.format('|'.join(stopwords.words('portuguese'))) 
feed_news['Without_stopwords'] = feed_news['Title_and_Content'].str.replace(pattern, '')

# %% [markdown]
# ### Removing punctuations

# %%
punctuations = [p for p in punctuation]

# %%
def remove_punctuations(text):    
    tokenizer = WordPunctTokenizer()
    words = tokenizer.tokenize(text)

    for word in words:
        words.remove(word) if word in punctuations else None

    return ' '.join(words)

# %%
feed_news['Without_punctuations'] = feed_news['Without_stopwords'].apply(remove_punctuations)

# %% [markdown]
# ### Removing accents

# %%
def remove_accents(text):
    return unidecode(text)

# %%
feed_news['Without_accents'] = feed_news['Without_punctuations'].apply(remove_accents)

# %% [markdown]
# ### Removing morphological affixes from words (Stemmer)

# %%
def stem_words(text):    
    tokenizer = WordPunctTokenizer()
    stemmer = RSLPStemmer()
    words = tokenizer.tokenize(text)
    stemmed_words = map(lambda word : stemmer.stem(word), words)

    return ' '.join(stemmed_words)

# %%
feed_news['Without_morphological_affixes'] = feed_news['Without_accents'].apply(stem_words)
feed_news
# Out:
#        Id                                              Title  \
# 0       1  Ex-executiva fala sobre vida sem propósito - I...
# 1       3  Todos os casos registrados em 10 anos por dele...
# 2       6  13 razões pelas quais crianças são bem mais es...
# 3       7                                      Conheça a PHC
# 4       8  11 coisas que você não sabia que era capaz de ...
# ..    ...                                                ...
# 991  1194                      Por que é importante meditar?
# 992  1195      Chegou sua hora de ser um Assinante Ribonito!
# 994  1197  As vencedoras deste concurso de fotografias de...
# 996  1199  Bloco de carnaval de BH tem bateria formada po...
# 998  1201  Botar o respeito na rua: 7 iniciativas que lut...
#
#                                                Content  \
# 0    Esqueça o que te disseram sobre a zona de conf...
# 1    Em dez anos, 465 vítimas – uma a cada semana, ...
# 2                 Temos muito o que aprender com elas.
# 3    Pelo fim da desnutrição no mundo - ONGs que ap...
# 4    Buzzfeed: Mas que a gente tem certeza que você...
# ..                                                 ...
# 991  Assim como qualquer pessoa, você provavelmente...
# 992  Experimente a assinatura de ribons pela metade...
# 994  Andamos tão obcecados pelas novas tecnologias ...
# 996  Uma bateria bastante especial faz o maior suce...
# 998  Chegou a época mais festiva do ano! O Carnaval...
#
#                                      Title_and_Content  \
# 0    ex-executiva fala sobre vida sem propósito - i...
# 1    todos os casos registrados em 10 anos por dele...
# 2    13 razões pelas quais crianças são bem mais es...
# 3    conheça a phc pelo fim da desnutrição no mundo...
# 4    11 coisas que você não sabia que era capaz de ...
# ..                                                 ...
# 991  por que é importante meditar? assim como qualq...
# 992  chegou sua hora de ser um assinante ribonito! ...
# 994  as vencedoras deste concurso de fotografias de...
# 996  bloco de carnaval de bh tem bateria formada po...
# 998  botar o respeito na rua: 7 iniciativas que lut...
#
#                                      Without_stopwords  \
# 0    ex-executiva fala sobre vida  propósito - ibc ...
# 1    todos  casos registrados  10 anos  delegacia e...
# 2    13 razões  quais crianças  bem  espertas   gen...
# 3    conheça  phc  fim  desnutrição  mundo - ongs  ...
# 4    11 coisas    sabia   capaz  fazer buzzfeed:   ...
# ..                                                 ...
# 991     importante meditar? assim  qualquer pessoa,...
# 992  chegou  hora  ser  assinante ribonito! experim...
# 994   vencedoras deste concurso  fotografias  paisa...
# 996  bloco  carnaval  bh  bateria formada  pessoas ...
# 998  botar  respeito  rua: 7 iniciativas  lutam   c...
#
#                                   Without_punctuations  \
# 0    ex executiva fala sobre vida propósito ibc coa...
# 1    todos casos registrados 10 anos delegacia espe...
# 2    13 razões quais crianças bem espertas gente ap...
# 3      conheça phc fim desnutrição mundo ongs apoiamos
# 4    11 coisas sabia capaz fazer buzzfeed gente cer...
# ..                                                 ...
# 991  importante meditar assim qualquer pessoa prova...
# 992  chegou hora ser assinante ribonito experimente...
# 994  vencedoras deste concurso fotografias paisagen...
# 996  bloco carnaval bh bateria formada pessoas defi...
# 998  botar respeito rua 7 iniciativas lutam carnava...
#
#                                        Without_accents  \
# 0    ex executiva fala sobre vida proposito ibc coa...
# 1    todos casos registrados 10 anos delegacia espe...
# 2    13 razoes quais criancas bem espertas gente ap...
# 3      conheca phc fim desnutricao mundo ongs apoiamos
# 4    11 coisas sabia capaz fazer buzzfeed gente cer...
# ..                                                 ...
# 991  importante meditar assim qualquer pessoa prova...
# 992  chegou hora ser assinante ribonito experimente...
# 994  vencedoras deste concurso fotografias paisagen...
# 996  bloco carnaval bh bateria formada pessoas defi...
# 998  botar respeito rua 7 iniciativas lutam carnava...
#
#                          Without_morphological_affixes
# 0    ex execu fal sobr vid proposit ibc coaching es...
# 1    tod cas registr 10 ano delegac especi g1 dez a...
# 2           13 razo qual crianc bem espert gent aprend
# 3              conhec phc fim desnutrica mund ong apoi
# 4      11 cois sab capaz faz buzzfeed gent cert conseg
# ..                                                 ...
# 991  import medit assim qualqu pesso prova acord pe...
# 992  cheg hor ser assin ribonit experim assinat rib...
# 994  venc dest concurs fotograf pais parec fotograf...
# 996  bloc carnav bh bat form pesso deficienc bat ba...
# 998  bot respeit rua 7 inici lut carnav livr precon...
#
# [894 rows x 8 columns]

# %% [markdown]
# # <span style="color:red">WordClouds and Frequency Distributions</span>

# %% [markdown]
# ### Function to generate wordclouds given a text

# %%
def generate_wordcloud(text, figsize=(20,8)):
    wordcloud = WordCloud(max_words=100, 
                          width=900,
                          height=500,
                          max_font_size=350,
                          collocations=False,
                          normalize_plurals=False).generate(text)
    plt.figure(figsize=figsize)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Function to get the full content and title in one string

# %%
def full_content_and_title(series):
    return series.str.cat(sep=" ")

# %% [markdown]
# ### Function to generate a frequency distribution

# %%
def generate_freq_dist_plot(text, max_words=25):
    words = WordPunctTokenizer().tokenize(text)
    words_that_apper_the_most = pd.Series(words).value_counts().nlargest(max_words)

    ax = sns.barplot(x=words_that_apper_the_most.index, y=words_that_apper_the_most.values)
    ax.figure.set_size_inches(20, 7)
    
    return words_that_apper_the_most

# %% [markdown]
# ### For raw data

# %%
text = full_content_and_title(feed_news['Title_and_Content'])

generate_wordcloud(text)
generate_freq_dist_plot(text)
# Out:
# ,       5340
# de      4773
# .       3231
# a       3093
# e       2691
# o       2425
# que     2005
# em      1500
# do      1454
# para    1425
# da      1336
# um       993
# com      979
# uma      943
# é        896
# no       879
# na       784
# os       631
# mais     603
# as       543
# por      505
# se       495
# como     476
# -        437
# não      409
# dtype: int64

# %% [markdown]
# ### Without stop  words

# %%
text = full_content_and_title(feed_news['Without_stopwords'])

generate_wordcloud(text)
generate_freq_dist_plot(text)
# Out:
# ,           5335
# .           3227
# -            417
# anos         373
# “            308
# (            299
# :            287
# pessoas      258
# mundo        232
# –            231
# ser          229
# !            213
# mulheres     202
# projeto      197
# brasil       187
# sobre        163
# vida         158
# crianças     144
# dia          138
# país         137
# )            136
# mil          128
# ”,           125
# ?            121
# ano          120
# dtype: int64

# %% [markdown]
# ### Without punctuations

# %%
text = full_content_and_title(feed_news['Without_punctuations'])

generate_wordcloud(text)
generate_freq_dist_plot(text)
# Out:
# anos        373
# “           308
# pessoas     258
# mundo       232
# –           231
# ser         229
# mulheres    202
# projeto     197
# brasil      187
# sobre       163
# vida        158
# crianças    144
# dia         138
# país        137
# mil         128
# ”,          125
# ano         120
# ‘           110
# história    108
# apenas      105
# pode        104
# todos       101
# ),          100
# além         99
# água         99
# dtype: int64

# %% [markdown]
# ### Without accents

# %%
text = full_content_and_title(feed_news['Without_accents'])
generate_wordcloud(text)
generate_freq_dist_plot(text)
# Out:
# "           410
# anos        373
# pessoas     258
# -           235
# mundo       232
# ser         229
# mulheres    202
# '           198
# projeto     197
# brasil      187
# sobre       163
# vida        158
# pais        155
# criancas    144
# ",          144
# dia         138
# mil         128
# ano         120
# historia    108
# apenas      105
# pode        105
# todos       101
# ),          100
# ainda        99
# agua         99
# dtype: int64

# %% [markdown]
# ### Without morphological affixes (Stemmed)

# %%
text = full_content_and_title(feed_news['Without_morphological_affixes'])
generate_wordcloud(text)
generate_freq_dist_plot(text)
# Out:
# ano        493
# "          410
# brasil     405
# mund       300
# pesso      279
# tod        262
# ser        254
# mulh       246
# -          235
# projet     235
# pod        220
# faz        217
# cri        208
# dia        200
# '          198
# prim       196
# ajud       183
# vid        183
# nov        182
# trabalh    180
# pass       179
# sobr       177
# crianc     165
# cas        157
# pal        155
# dtype: int64
